# %% [markdown]
# ## mean reverison
#
# - key words
#     - theory-driven alpha models
#     - price-related data

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import QUANTAXIS as QA
import pandas as pd
import numpy as np
import datetime, time

# %%
from utils import *

# %%
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'
plt.style.use('ggplot')

# %% [markdown]
# 使用沪深300和中证500作为比较标的

# %% [markdown]
# 1. 取数
# 2. 处理数据
# 3. 数据可视化

# %% [markdown]
# ### retrieve data

# %%
code = ['000300', '000905']
start = '2018-01-01'
end = datetime.datetime.today().strftime('%Y-%m-%d')

# %%
data_day = QA.QA_fetch_index_day_adv(code, start, end)

# %%
plot_series(data_day.select_code(code[1]).data.reset_index().set_index('date').loc[:,['close']], code[1])

plot_series(data_day.data.loc[(slice(None), code[0]), ['close']], code[0])

# %%
plot_series(data_day.data.loc[:,['close']], code)

# %%
df_hs300 = data_day.select_code(code[0]).data.reset_index().set_index('date')
df_zz500 = data_day.select_code(code[1]).data.reset_index().set_index('date')

# %%
# df_spread = pd.DataFrame({'spread': (df_hs300.close - df_zz500.close) - (df_hs300.close - df_zz500.close).diff(5)})
df_spread = pd.DataFrame({'spread': (df_hs300.close - df_zz500.close) - QA.MA(df_hs300.close - df_zz500.close, 5)})

# %%
plot_series(df_spread, '')

# %%
from statsmodels.tsa.stattools import adfuller as ADF

# %%
ADF(df_spread.values[4:])
# Out:
# (-9.175920148426219,
#  2.3204225538253915e-15,
#  4,
#  580,
#  {'1%': -3.4416749612171467,
#   '5%': -2.8665360672844318,
#   '10%': -2.5694307639714626},
#  5659.115810637231)

# %%
import pandas_datareader.data as web
import os

# %%
os.environ['ALPHAVANTAGE_API_KEY'] = 'PSGPY5QSQJIH3XP8'

# %%
df = web.DataReader(["SCHW", "MER"], 
                   "av-daily", 
                   start= datetime.datetime(2004, 1, 1), 
                   end= datetime.datetime(2006, 12, 31),
                   api_key='PSGPY5QSQJIH3XP8')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-9593fb1ca3d4> in <module>
#       3                    start= datetime.datetime(2004, 1, 1),
#       4                    end= datetime.datetime(2006, 12, 31),
# ----> 5                    api_key=os.getenv('ALPHAVANTAGE_API_KEY'))
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\pandas_datareader\data.py in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     577             pause=pause,
#     578             session=session,
# ...

# %%
f = web.DataReader("AAPL", "av-daily", start=datetime.datetime(2017, 2, 9),
                   end=datetime.datetime(2017, 5, 24),
                   api_key='PSGPY5QSQJIH3XP8')
# Out:
# ---------------------------------------------------------------------------
# IncompleteRead                            Traceback (most recent call last)
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\urllib3\response.py in _error_catcher(self)
#     424             try:
# --> 425                 yield
#     426
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\urllib3\response.py in read_chunked(self, amt, decode_content)
#     754                     break
# --> 755                 chunk = self._handle_chunk(amt)
#     756                 decoded = self._decode(
#
# E:\ProgramData\Anaconda3\envs\quant\lib\site-packages\urllib3\response.py in _handle_chunk(self, amt)
#     698         elif amt < self.chunk_left:
# --> 699             value = self._fp._safe_read(amt)
#     700             self.chunk_left = self.chunk_left - amt
#
# E:\ProgramData\Anaconda3\envs\quant\lib\http\client.py in _safe_read(self, amt)
#     621             if not chunk:
# ...

# %%
from alpha_vantage.timeseries import TimeSeries
from alpha_vantage.techindicators import TechIndicators
from matplotlib.pyplot import figure
import os
# import matplotlib.pyplot as plt

# Your key here
key = 'PSGPY5QSQJIH3XP8'
# Chose your output format, or default to JSON (python dict)
ts = TimeSeries(key, output_format='pandas')
ti = TechIndicators(key)

# %%
# Get the data, returns a tuple
# aapl_data is a pandas dataframe, aapl_meta_data is a dict
aapl_data, aapl_meta_data = ts.get_daily(symbol='AAPL')
# aapl_sma is a dict, aapl_meta_sma also a dict
aapl_sma, aapl_meta_sma = ti.get_sma(symbol='AAPL')

# %%
aapl_data.head()
# Out:
#             1. open  2. high  3. low  4. close   5. volume
# date
# 2020-01-14   316.70   317.57  312.17    312.68  40653457.0
# 2020-01-15   311.85   315.50  309.55    311.34  30480882.0
# 2020-01-16   313.59   315.70  312.09    315.24  27207254.0
# 2020-01-17   316.27   318.74  315.00    318.73  34454117.0
# 2020-01-21   317.19   319.02  316.00    316.57  27235039.0

# %%
# Visualization
figure(num=None, figsize=(15, 6), dpi=80, facecolor='w', edgecolor='k')
aapl_data['4. close'].plot()
plt.tight_layout()
plt.grid()
plt.show()

# %%
import pandas as pd
import io
import requests

# %%
apikey = 'PSGPY5QSQJIH3XP8'

url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&outputsize=full&symbol=MSFT&apikey=' + apikey + '&datatype=csv'

s = requests.get(url).content

stock = pd.read_csv(io.StringIO(s.decode('utf-8')))

# %%
stock.shape
# Out:
# (5033, 6)
